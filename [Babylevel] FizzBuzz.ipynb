# %%
#This Project is finished just to fill up all project ideas.

# %%
'''
Fizz Buzz Write a program that prints the numbers from 1 to 100. But for multiples of three print “Fizz” instead of the number and for the multiples of five print “Buzz”. 
For numbers which are multiples of both three and five print “FizzBuzz”.
'''

# %%
def FizzBuzz(n):
    for x in range(n):
        if n%3==0 and n%5==0:
            print('FizzBuzz')
            pass
        elif n%3==0:
            print('Fizz')
            pass
        elif n%5==0:
            print('Buzz')
            pass
        else:
            print(n)

# %%
FizzBuzz(100)
# Out:
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
# Buzz
