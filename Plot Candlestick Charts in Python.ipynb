# %%
#Another topics that I have already understanded, so this would just be like a toolbox for me
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import pandas_datareader as web
import mplfinance as mpf
import pandas as pd

start = dt.datetime(2021,3,1)
end = dt.datetime.now()

df = web.DataReader('AAPL', 'yahoo', start, end)

mpf.plot(df,type='candle')

# %% [markdown]
# https://github.com/matplotlib/mplfinance
#
# https://stackoverflow.com/questions/67225879/how-can-i-deal-with-expect-data-index-as-datetimeindex

# %%
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-03-01  127.930000  122.790001  123.750000  127.790001  116307900.0
# 2021-03-02  128.720001  125.010002  128.410004  125.120003  102260900.0
# 2021-03-03  125.709999  121.839996  124.809998  122.059998  112966300.0
# 2021-03-04  123.599998  118.620003  121.750000  120.129997  178155000.0
# 2021-03-05  121.940002  117.570000  120.980003  121.419998  153766600.0
# 2021-03-08  121.000000  116.209999  120.930000  116.360001  154376600.0
# 2021-03-09  122.059998  118.790001  119.029999  121.089996  129525800.0
# 2021-03-10  122.169998  119.449997  121.690002  119.980003  111943300.0
# 2021-03-11  123.209999  121.260002  122.540001  121.959999  103026500.0
# 2021-03-12  121.169998  119.160004  120.400002  121.029999   88105100.0
# 2021-03-15  124.000000  120.419998  121.410004  123.989998   92403800.0
# 2021-03-16  127.220001  124.720001  125.699997  125.570000  115227900.0
# ...
